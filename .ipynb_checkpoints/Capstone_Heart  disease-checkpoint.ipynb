# %%
#Heart Disease Prediction Using Gradio

# %%
#Objective of this project

#Heart disease: A leading cause of death globally.
#Early prediction can save lives.
#This project aims to develop a predictive model using machine learning.
#Utilizes Gradio for an interactive interface.

# %%
#Information of datasets  
#Dataset downloaded from heart_info.csv
#Heart_info has 1025 rows x 14 columns

# %%
#Here's a humorous and catchy song about predicting heart disease using the heart_info.csv dataset. 
#Think of it as a fun, educational jingle to make learning about heart disease

#Verse 1: We got a dataset, so fine and so neat,
#Heart_info.csv, it can’t be beat!
#Age and sex, and the chest pain type,
#Get your data ready, let's get this right!

#Chorus: Oh, we’re predicting heart disease,
#With FBS, Chol, and a bit of expertise!
#From the ECG to the Thalach score,
#We’re crunching all the numbers, and we’re asking for more!

#Verse 2: Trestbps is the pressure, keep it on track,
#Oldpeak’s the measure, there’s no turning back.
#Exang tells us if exercise brings a fright,
#While Slope and CA give us insight.

#Chorus: Oh, we’re predicting heart disease,
#With FBS, Chol, and a bit of expertise!
#From the ECG to the Thalach score,
#We’re crunching all the numbers, and we’re asking for more!

#Bridge: Thalassemia, it’s a type that you see,
#Normal or fixed, or reversible, maybe?
#We’re using all these features, to get the best fit,
#To predict if your heart is in a bit of a split.

#Chorus: Oh, we’re predicting heart disease,
#With FBS, Chol, and a bit of expertise!
#From the ECG to the Thalach score,
#We’re crunching all the numbers, and we’re asking for more!

#Outro: So let’s dive into the data, don’t be afraid,
#Heart_info.csv’s the game we’ve played.
#With a little bit of humor and a lot of brains,
#We’ll keep those hearts healthy and break all the chains!

# %%
pip install prettytable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from prettytable import PrettyTable

# Create a PrettyTable object
table = PrettyTable()

# Define columns
table.field_names = ["Variable", "Description", "Role"]

# Add rows
table.add_row(["Age", "Patient’s age.", "Older age = higher risk."])
table.add_row(["Sex", "Gender (1 = male, 0 = female).", "Males have higher risk."])
table.add_row(["CP", "Chest pain type: 0: Typical, 1: Atypical, 2: Non-anginal, 3: Asymptomatic", "Indicates severity."])
table.add_row(["Trestbps", "Resting blood pressure (mm Hg).", "Higher pressure = higher risk."])
table.add_row(["Chol", "Serum cholesterol (mg/dl).", "Higher cholesterol = higher risk."])
table.add_row(["FBS", "Fasting blood sugar > 120 mg/dl (1 = True; 0 = False).", "High sugar = diabetes risk."])
table.add_row(["Restecg", "ECG results: 0: Normal, 1: Abnormal, 2: Hypertrophy", "Indicates heart issues."])
table.add_row(["Thalach", "Max heart rate during exercise.", "Lower rate = poor heart health."])
table.add_row(["Exang", "Exercise-induced angina (1 = Yes; 0 = No).", "Indicates coronary disease."])
table.add_row(["Oldpeak", "ST depression from exercise.", "Higher values = ischemia."])
table.add_row(["Slope", "ST segment slope: 0: Upsloping, 1: Flat, 2: Downsloping", "Downsloping = severe disease."])
table.add_row(["CA", "Major vessels colored (0 to 3).", "More vessels = more blockage."])
table.add_row(["Thal", "Thalassemia type: 0: Normal, 1: Fixed, 2: Reversible", "Affects oxygen transport."])
table.add_row(["Target", "Heart disease (1 = Yes; 0 = No).", "Output variable."])

# Display the table
print(table)
# Out:
# +----------+---------------------------------------------------------------------------+-----------------------------------+
# | Variable |                                Description                                |                Role               |
# +----------+---------------------------------------------------------------------------+-----------------------------------+
# |   Age    |                               Patient’s age.                              |      Older age = higher risk.     |
# |   Sex    |                       Gender (1 = male, 0 = female).                      |      Males have higher risk.      |
# |    CP    | Chest pain type: 0: Typical, 1: Atypical, 2: Non-anginal, 3: Asymptomatic |        Indicates severity.        |
# | Trestbps |                      Resting blood pressure (mm Hg).                      |   Higher pressure = higher risk.  |
# ...

# %%
# Example data for pie chart
import matplotlib.pyplot as plt
import pandas as pd
labels = ['Age', 'Sex', 'CP', 'Trestbps', 'Chol', 'FBS', 'Restecg', 'Thalach', 'Exang', 'Oldpeak', 'Slope', 'CA', 'Thal', 'Target']
sizes = [1] * 14  # Just an example with equal size for each

# Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=plt.get_cmap('tab20').colors)
plt.title('Name of variables in the data frame')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
import warnings
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn import linear_model, tree, ensemble

# %%
df = pd.read_csv(r"C:\Users\lenovo\Downloads\heart\heart_info.csv")
print(df)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# EDA and Data Preparation

# %%
#Understanding data in different ways¶

print("Dimension of the data:", df.shape)

print("\n", "--" * 50, "\n")

print("Summary of the data\n") 
display(df.info())

print("\n", "--" * 50, "\n")

print("Missing values in the entire dataframe\n")

display(df.isnull().sum().sum())

print("\n", "--" * 50, "\n")

print("Statistical description:") 
display(df.describe())
# Out:
# Dimension of the data: (1025, 14)
#
#  ----------------------------------------------------------------------------------------------------
#
# Summary of the data
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# None
# ...

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#  Bar Charts
#Bar charts are generally used for categorical data.

# %%
# Map the 'sex' column to human-readable values
#df['sex'] = df['sex'].map({0: 'Female', 1: 'Male'})

# Now create the bar chart with updated labels
#plt.figure(figsize=(8, 6))
#sns.countplot(data=df, x='sex', palette='viridis')
#plt.title('Sex Distribution')
#plt.show()

# %% [markdown]
# #Histograms
# #Histograms are used for continuous numerical data

# %%
# Example: Histogram for the "age" column
#plt.figure(figsize=(8, 6))
#plt.hist (df['age'], bins=20, color='skyblue', edgecolor='black')
#plt.title('Age Distribution of Patients')
#plt.xlabel('Age')
#plt.ylabel('Frequency')
#plt.show()

# %%
#Correlation matrix
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),linewidth=.01,annot=True,cmap="coolwarm")
plt.show()
plt.savefig('correlationfigure')

# %%
 #This shows that most columns are moderately correlated with target, but 'fbs' is very weakly correlated.

# %%
 df.hist(figsize=(12,12))
plt.savefig('featuresplot')

# %%
dfCorr = df.corr()
filteredDf = dfCorr[((dfCorr > 0.5) | (dfCorr < -0.5)) & (dfCorr !=1.000)]
display(filteredDf)
# Out:
#           age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# age       NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# sex       NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# cp        NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# trestbps  NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# chol      NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# fbs       NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# restecg   NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# thalach   NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# exang     NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# oldpeak   NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# slope     NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# ca        NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# thal      NaN  NaN NaN       NaN   NaN  NaN      NaN      NaN    NaN
# ...

# %%
y = df["target"]

sns.countplot(x=y, hue=y, palette="Set1", legend=False)

target_temp = df.target.value_counts()

print(target_temp)
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
#Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X = df.drop("target",axis=1)
y = df["target"]

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.20,random_state=40)

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
lr=LogisticRegression(max_iter=500)
model_lr=lr.fit(X_train,y_train)
prediction_lr=model_lr.predict(X_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,prediction_lr)

sns.heatmap(cm, annot=True,cmap='winter',linewidths=0.3, linecolor='black',annot_kws={"size": 20})



accuracy = accuracy_score(y_test, prediction_lr)
print(f"Logistic Regression  Accuracy: {accuracy}")

sensitivity = recall_score(y_test, prediction_lr, pos_label=1)  # Assuming class 1 is the positive class
print(f"Logistic Regression Sensitivity (Recall): {sensitivity}")

specificity = recall_score(y_test, prediction_lr, pos_label=0)  # Assuming class 0 is the negative class
print(f"Logistic Regression Specificity (True Negative Rate): {specificity}")

precision = precision_score(y_test, prediction_lr, pos_label=1)  # Assuming class 1 is the positive class
print(f"Logistic Regression Precision (Positive Predictive Value): {precision:}")
# Out:
# Logistic Regression  Accuracy: 0.824390243902439
# Logistic Regression Sensitivity (Recall): 0.8725490196078431
# Logistic Regression Specificity (True Negative Rate): 0.7766990291262136
# Logistic Regression Precision (Positive Predictive Value): 0.7946428571428571

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82       103
#            1       0.79      0.87      0.83       102
#
#     accuracy                           0.82       205
#    macro avg       0.83      0.82      0.82       205
# weighted avg       0.83      0.82      0.82       205

# %%
#Decision Tree

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier

model_dt = DecisionTreeClassifier(max_depth=5,criterion='gini')
cv_scores = cross_val_score(model_dt, X, y, cv=10, scoring='accuracy')
m=model_dt.fit(X, y)
prediction_dt=m.predict(X_test)
cm= confusion_matrix(y_test,prediction_dt)
sns.heatmap(cm, annot=True,cmap='winter',linewidths=0.3, linecolor='black',annot_kws={"size": 20})

print(classification_report(y_test, prediction_dt))



accuracy = accuracy_score(y_test, prediction_dt)
print(f"Decision Tree Accuracy: {accuracy}")

sensitivity = recall_score(y_test, prediction_dt, pos_label=1)  # Assuming class 1 is the positive class
print(f"Decision Tree Sensitivity (Recall): {sensitivity}")

specificity = recall_score(y_test, prediction_dt, pos_label=0)  # Assuming class 0 is the negative class
print(f"Decision Tree Specificity (True Negative Rate): {specificity}")

precision = precision_score(y_test, prediction_dt, pos_label=1)  # Assuming class 1 is the positive class
print(f"Decision Tree Precision (Positive Predictive Value): {precision:}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       103
#            1       0.92      0.95      0.93       102
#
#     accuracy                           0.93       205
#    macro avg       0.93      0.93      0.93       205
# weighted avg       0.93      0.93      0.93       205
#
# Decision Tree Accuracy: 0.9317073170731708
# Decision Tree Sensitivity (Recall): 0.9509803921568627
# Decision Tree Specificity (True Negative Rate): 0.912621359223301
# Decision Tree Precision (Positive Predictive Value): 0.9150943396226415

# %%
#Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=2000,criterion='gini',max_depth=8,min_samples_split=5)
model_rfc = rfc.fit(X_train, y_train)
prediction_rfc = model_rfc.predict(X_test)
cm_rfc=confusion_matrix(y_test, prediction_rfc)
sns.heatmap(cm_rfc, annot=True,cmap='winter',linewidths=0.3, linecolor='black',annot_kws={"size": 20})

print(classification_report(y_test, prediction_rfc))

accuracy = accuracy_score(y_test, prediction_rfc)
print(f"Random Forest Accuracy: {accuracy}")

sensitivity = recall_score(y_test, prediction_rfc, pos_label=1)  # Assuming class 1 is the positive class
print(f"Random Forest Sensitivity (Recall): {sensitivity}")

specificity = recall_score(y_test, prediction_rfc, pos_label=0)  # Assuming class 0 is the negative class
print(f"Random Forest Specificity (True Negative Rate): {specificity}")

precision = precision_score(y_test, prediction_rfc, pos_label=1)  # Assuming class 1 is the positive class
print(f"Random Forest Precision (Positive Predictive Value): {precision:}")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       103
#            1       1.00      1.00      1.00       102
#
#     accuracy                           1.00       205
#    macro avg       1.00      1.00      1.00       205
# weighted avg       1.00      1.00      1.00       205
#
# Random Forest Accuracy: 1.0
# Random Forest Sensitivity (Recall): 1.0
# Random Forest Specificity (True Negative Rate): 1.0
# Random Forest Precision (Positive Predictive Value): 1.0

# %%
#Support Vector Machines(SVM)

# %%
from sklearn import svm
sv = svm.SVC(kernel='linear')
model_svm = sv.fit(X_train, y_train)
prediction_svm = model_svm.predict(X_test)
cm_svm = confusion_matrix(y_test,prediction_svm)
sns.heatmap(cm_svm, annot=True,cmap='winter',linewidths=0.3, linecolor='black',annot_kws={"size": 20})

print(classification_report(y_test, prediction_svm))

accuracy = accuracy_score(y_test, prediction_svm)
print(f"SVM Accuracy: {accuracy}")

sensitivity = recall_score(y_test, prediction_svm, pos_label=1)  # Assuming class 1 is the positive class
print(f"SVM Sensitivity (Recall): {sensitivity}")

specificity = recall_score(y_test, prediction_svm, pos_label=0)  # Assuming class 0 is the negative class
print(f"SVM Specificity (True Negative Rate): {specificity}")

precision = precision_score(y_test, prediction_svm, pos_label=1)  # Assuming class 1 is the positive class
print(f"SVM Precision (Positive Predictive Value): {precision:}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.84       103
#            1       0.81      0.93      0.86       102
#
#     accuracy                           0.85       205
#    macro avg       0.86      0.85      0.85       205
# weighted avg       0.86      0.85      0.85       205
#
# SVM Accuracy: 0.8536585365853658
# SVM Sensitivity (Recall): 0.9313725490196079
# SVM Specificity (True Negative Rate): 0.7766990291262136
# SVM Precision (Positive Predictive Value): 0.8050847457627118

# %%
 df.head(150)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 145   40    1   0       110   167    0        0      114      1      2.0
# 146   51    0   2       120   295    0        0      157      0      0.6
# 147   41    1   0       110   172    0        0      158      0      0.0
# 148   52    1   3       152   298    1        1      178      0      1.2
# 149   39    1   2       140   321    0        0      182      0      0.0
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
input=(70,1,1,156,245,0,0,143,0,0.0,2,0,2)
input_as_numpy=np.asarray(input)
input_reshaped=input_as_numpy.reshape(1,-1)
final_prediction=model_dt.predict(input_reshaped)
#print(final_prediction)
if(final_prediction==1): 
  print("The patient may be at risk for heart disease :(")
else:
  print("No sign of heart disease at this time :)")
# Out:
# The patient may be at risk for heart disease :(

# %%
input=(35,1,0,126,282,0,0,156,1,0.0,2,0,3)
input_as_numpy=np.asarray(input)
input_reshaped=input_as_numpy.reshape(1,-1)
final_prediction=model_dt.predict(input_reshaped)
#print(final_prediction)
if(final_prediction==1): 
  print("The patient may be at risk for heart disease :(")
else:
  print("No sign of heart disease at this time :)")
# Out:
# No sign of heart disease at this time :)

# %%
# !pip install gradio

# %%
import gradio as gr
import numpy as np
import pickle

# Load your trained model (Assuming you have it as a pickle file)
#model = pickle.load(open("heart_disease_model.pkl", "rb"))

# Define the prediction function
def predict_heart_disease(age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal,target):
 # Example input array based on the features
 input_data = np.array([age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal,target])

# %%
#df.head()

# %%
# Create the Gradio interface
interface = gr.Interface(
    fn=predict_heart_disease,
    inputs=[
        gr.Number(label="Age"),
        gr.Radio(["Male", "Female"], label="Sex", type="index"),  # Male: 1, Female: 0
        gr.Dropdown(["0", "1", "2", "3"], label="Chest Pain Type (cp)"),
        gr.Number(label="Resting Blood Pressure (trestbps)"),
        gr.Number(label="Cholesterol (chol)"),
        gr.Radio(["Yes", "No"], label="Fasting Blood Sugar > 120 mg/dl (fbs)", type="index"),  # Yes: 1, No: 0
        gr.Dropdown(["0", "1", "2"], label="Resting ECG Results (restecg)"),
        gr.Number(label="Maximum Heart Rate Achieved (thalach)"),
        gr.Radio(["Yes", "No"], label="Exercise Induced Angina (exang)", type="index"),  # Yes: 1, No: 0
        gr.Number(label="Oldpeak (ST Depression)"),
        gr.Dropdown(["0", "1", "2"], label="Slope of Peak Exercise ST Segment (slope)"),
        gr.Number(label="Number of Major Vessels (ca)"),
        gr.Dropdown(["3", "6", "7"], label="Thalassemia (thal)")
            ],
    outputs=[
        gr.JSON(label="Prediction and Model Metrics")
    ],
    title="Heart Disease Prediction using Random Forest",
    description="Enter medical details to predict heart disease and see model performance metrics."
)

# Launch the Gradio interface
interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already split the data into X_train, X_test, y_train, y_test

# Define the Decision Tree model
model_dt = DecisionTreeClassifier(max_depth=5, criterion='gini')
model_dt.fit(X_train, y_train)

# Define the prediction function for Gradio
def predict_heart_disease(age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal):
    # Prepare input data for prediction
    input_data = np.array([[age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal]])
    
    # Predict whether the person has heart disease
    prediction = model_dt.predict(input_data)
    
    # Calculate performance metrics on the test set
    prediction_dt = model_dt.predict(X_test)
    accuracy = accuracy_score(y_test, prediction_dt)
    sensitivity = recall_score(y_test, prediction_dt, pos_label=1)  # Sensitivity (Recall) for class 1
    specificity = recall_score(y_test, prediction_dt, pos_label=0)  # Specificity for class 0
    precision = precision_score(y_test, prediction_dt, pos_label=1)  # Precision for class 1

    # Display confusion matrix as a heatmap
    cm = confusion_matrix(y_test, prediction_dt)
    sns.heatmap(cm, annot=True, cmap='winter', linewidths=0.3, linecolor='black', annot_kws={"size": 20})
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    # Return prediction and metrics
    result = {
        "Prediction": "Heart Disease Detected" if prediction[0] == 1 else "No Heart Disease",
        "Accuracy": f"{accuracy:.2f}",
        "Sensitivity (Recall)": f"{sensitivity:.2f}",
        "Specificity": f"{specificity:.2f}",
        "Precision": f"{precision:.2f}"
    }

    return result

# Create the Gradio interface
interface = gr.Interface(
    fn=predict_heart_disease,
    inputs=[
        gr.Number(label="Age"),
        gr.Radio(["Male", "Female"], label="Sex", type="index"),  # Male: 1, Female: 0
        gr.Dropdown(["0", "1", "2", "3"], label="Chest Pain Type (cp)"),
        gr.Number(label="Resting Blood Pressure (trestbps)"),
        gr.Number(label="Cholesterol (chol)"),
        gr.Radio(["Yes", "No"], label="Fasting Blood Sugar > 120 mg/dl (fbs)", type="index"),  # Yes: 1, No: 0
        gr.Dropdown(["0", "1", "2"], label="Resting ECG Results (restecg)"),
        gr.Number(label="Maximum Heart Rate Achieved (thalach)"),
        gr.Radio(["Yes", "No"], label="Exercise Induced Angina (exang)", type="index"),  # Yes: 1, No: 0
        gr.Number(label="Oldpeak (ST Depression)"),
        gr.Dropdown(["0", "1", "2"], label="Slope of Peak Exercise ST Segment (slope)"),
        gr.Number(label="Number of Major Vessels (ca)"),
        gr.Dropdown(["3", "6", "7"], label="Thalassemia (thal)")
    ],
    outputs=[
        gr.JSON(label="Prediction and Model Metrics")
    ],
    title="Heart Disease Prediction using Decision Tree",
    description="Enter medical details to predict heart disease and see model performance metrics."
)

# Launch the Gradio interface
interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import numpy as np
from sklearn import svm
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already split the data into X_train, X_test, y_train, y_test
# and trained your SVM model

# Define the SVM model
sv = svm.SVC(kernel='linear')
model_svm = sv.fit(X_train, y_train)

def predict_heart_disease(age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal):
    # Prepare input data for prediction
    input_data = np.array([[age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal]])
    
    # Predict whether the person has heart disease
    prediction = model_svm.predict(input_data)
    
    # Calculate performance metrics on the test set
    prediction_svm = model_svm.predict(X_test)
    accuracy = accuracy_score(y_test, prediction_svm)
    sensitivity = recall_score(y_test, prediction_svm, pos_label=1)  # Sensitivity (Recall) for class 1
    specificity = recall_score(y_test, prediction_svm, pos_label=0)  # Specificity for class 0
    precision = precision_score(y_test, prediction_svm, pos_label=1)  # Precision for class 1

    # Display confusion matrix as a heatmap
    cm = confusion_matrix(y_test, prediction_svm)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, cmap='winter', linewidths=0.3, linecolor='black', annot_kws={"size": 20})
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    # Return prediction and metrics
    result = {
        "Prediction": "Heart Disease Detected" if prediction[0] == 1 else "No Heart Disease",
        "Accuracy": f"{accuracy:.2f}",
        "Sensitivity (Recall)": f"{sensitivity:.2f}",
        "Specificity": f"{specificity:.2f}",
        "Precision": f"{precision:.2f}"
    }

    return result

# Create the Gradio interface
interface = gr.Interface(
    fn=predict_heart_disease,
    inputs=[
        gr.Number(label="Age"),
        gr.Radio(["Male", "Female"], label="Sex", type="index"),  # Male: 1, Female: 0
        gr.Dropdown(["0", "1", "2", "3"], label="Chest Pain Type (cp)"),
        gr.Number(label="Resting Blood Pressure (trestbps)"),
        gr.Number(label="Cholesterol (chol)"),
        gr.Radio(["Yes", "No"], label="Fasting Blood Sugar > 120 mg/dl (fbs)", type="index"),  # Yes: 1, No: 0
        gr.Dropdown(["0", "1", "2"], label="Resting ECG Results (restecg)"),
        gr.Number(label="Maximum Heart Rate Achieved (thalach)"),
        gr.Radio(["Yes", "No"], label="Exercise Induced Angina (exang)", type="index"),  # Yes: 1, No: 0
        gr.Number(label="Oldpeak (ST Depression)"),
        gr.Dropdown(["0", "1", "2"], label="Slope of Peak Exercise ST Segment (slope)"),
        gr.Number(label="Number of Major Vessels (ca)"),
        gr.Dropdown(["3", "6", "7"], label="Thalassemia (thal)")
    ],
    outputs=[
        gr.JSON(label="Prediction and Model Metrics")
    ],
    title="Heart Disease Prediction using SVM",
    description="Enter medical details to predict heart disease and see model performance metrics."
)

# Launch the Gradio interface
interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
#  Taking care of your heart is an investment in your overall health and well-being
